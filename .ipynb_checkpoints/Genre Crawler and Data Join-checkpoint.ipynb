# %%
import pandas as pd
import requests
import bs4
import os
import re
import time

# %%
os.chdir("D:\user\Documents\WebMining\data")

# %%
file_list = []
for i in os.listdir():
    if "k.csv"in i:
        file_list.append(i)
print(file_list)
# Out:
# ['book1-100k.csv', 'book1000k-1100k.csv', 'book100k-200k.csv', 'book1100k-1200k.csv', 'book1200k-1300k.csv', 'book1300k-1400k.csv', 'book1400k-1500k.csv', 'book1500k-1600k.csv', 'book1600k-1700k.csv', 'book1700k-1800k.csv', 'book1800k-1900k.csv', 'book1900k-2000k.csv', 'book2000k-3000k.csv', 'book200k-300k.csv', 'book3000k-4000k.csv', 'book300k-400k.csv', 'book4000k-5000k.csv', 'book400k-500k.csv', 'book500k-600k.csv', 'book600k-700k.csv', 'book700k-800k.csv', 'book800k-900k.csv', 'book900k-1000k.csv']

# %%
# get original columns for append
init_column = pd.read_csv(file_list[0]).columns
# create a big df for crawler and id-join
final_df = pd.DataFrame(columns=init_column)
for i in file_list:
    final_df = final_df.append(pd.read_csv(i))

# %%
final_df = final_df.reset_index(drop= True)
final_df = final_df.drop_duplicates()
final_df
# Out:
#              Id                                               Name  \
# 0             1  Harry Potter and the Half-Blood Prince (Harry ...
# 1             2  Harry Potter and the Order of the Phoenix (Har...
# 2             3  Harry Potter and the Sorcerer's Stone (Harry P...
# 3             4  Harry Potter and the Chamber of Secrets (Harry...
# 4             5  Harry Potter and the Prisoner of Azkaban (Harr...
# ...         ...                                                ...
# 1850305  999991  Gendered Talk at Work: Constructing Gender Ide...
# 1850306  999992  Good Will Toward Men: Women Talk Candidly abou...
# 1850307  999993  Would You Rather . . . ?: The Outrageous Book ...
# 1850308  999997  Addictions Treatment for Older Adults: Evaluat...
# 1850309  999998                                     Within/Without
#
#         RatingDist1 pagesNumber RatingDist4 RatingDistTotal PublishMonth  \
# 0            1:9896         652    4:556485   total:2298124           16
# 1           1:12455         870    4:604283   total:2358637            1
# 2          1:108202         309   4:1513191   total:6587388            1
# 3           1:11896         352    4:706082   total:2560657            1
# 4           1:10128         435    4:630534   total:2610317            1
# ...             ...         ...         ...             ...          ...
# 1850305         1:0         251         4:3        total:25           21
# 1850306         1:0         231         4:0         total:0            1
# 1850307         1:2         400        4:35       total:121            1
# 1850308         1:0         258         4:0         total:0            2
# 1850309         1:0          36         4:0         total:2            1
#
#         PublishDay                   Publisher CountsOfReview  ... Language  \
# 0                9             Scholastic Inc.          28062  ...      eng
# 1                9             Scholastic Inc.          29770  ...      eng
# 2               11              Scholastic Inc          75911  ...      eng
# 3               11                  Scholastic            244  ...      eng
# 4                5             Scholastic Inc.          37093  ...      eng
# ...            ...                         ...            ...  ...      ...
# 1850305          7             Wiley-Blackwell              0  ...      NaN
# 1850306          2          St. Martin's Press              0  ...      NaN
# 1850307         10  Workman Publishing Company             14  ...      NaN
# 1850308          2                   Routledge              0  ...      NaN
# 1850309          3      Pilgrims Process, Inc.              0  ...      NaN
#
#                    Authors Rating  RatingDist2 RatingDist5        ISBN  \
# 0             J.K. Rowling   4.57      2:25317   5:1546466         NaN
# 1             J.K. Rowling   4.50      2:37005   5:1493113  0439358078
# 2             J.K. Rowling   4.47     2:130310   5:4268227         NaN
# 3             J.K. Rowling   4.42      2:49353   5:1504505  0439554896
# 4             J.K. Rowling   4.57      2:24849   5:1749958  043965548X
# ...                    ...    ...          ...         ...         ...
# 1850305      Janet  Holmes   4.28          2:1        5:15  1405117591
# 1850306        Jack Kammer   0.00          2:0         5:0  0312104715
# 1850307         Randy Horn   3.81         2:11        5:39  0761124209
# 1850308     Kathryn Graham   0.00          2:0         5:0  1560248572
# 1850309  Kathryn T.S. Bass   5.00          2:0         5:2  097495974X
#
#         RatingDist3                                        Description  \
# 0          3:159960                                                NaN
# 1          3:211781                                                NaN
# 2          3:567458                                                NaN
# 3          3:288821                                                NaN
# 4          3:194848                                                NaN
# ...             ...                                                ...
# 1850305         3:6  <i>Gendered Talk at Work</i> examines how wome...
# 1850306         3:0  In interviews with gender issues journalist Ja...
# 1850307        3:34  <i>Would You Rather...?</i> takes the idea of ...
# 1850308         3:0  Here is a detailed description of an innovativ...
# 1850309         3:0                                                NaN
#
#         Count of text reviews  PagesNumber
# 0                         NaN          NaN
# 1                         NaN          NaN
# 2                         NaN          NaN
# 3                         NaN          NaN
# 4                         NaN          NaN
# ...                       ...          ...
# 1850305                   0.0          NaN
# 1850306                   0.0          NaN
# 1850307                  14.0          NaN
# 1850308                   0.0          NaN
# 1850309                   0.0          NaN
#
# [1850198 rows x 21 columns]

# %%
Books = pd.read_csv("Books.csv")
# Out:
# C:\Users\Austin\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3326: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
Genre_df = final_df.copy()
# drop NA value in ISBN
Genre_df= Genre_df.loc[Genre_df.ISBN.dropna().index,:]
# filter by ISBN
Genre_df = Genre_df.merge(Books,on = "ISBN")
# generate empty columns
Genre_df.loc[:,"Genre"] = ""
Genre_df.loc[:,"Genre_user_amount"] = ""

# %%
# Crawler
def Crawler(ID = 1):
    genre_string = ""
    genre_users_string = ""
    response  = requests.get(f"https://www.goodreads.com/book/show/{ID}")
    soup = bs4.BeautifulSoup(response.text, "html.parser")
    genre_list = soup.find_all("a", {"class": "bookPageGenreLink"})
    genre_amount = soup.find_all("div", {"class": "bookPageGenreLink"})
    for i in range(min(len(genre_list),len(genre_amount))):
        genre_string += genre_list[i].text
        m = re.search(r"(\d{0,3},?\d{0,3},?\d{0,3}) users",genre_amount[i].text)
        genre_users_string +=  m.group(1)

        genre_string += "|"
        genre_users_string += "|"
    time.sleep(0.05)
    return genre_string, genre_users_string

# %%
break_point = 20
for k in range(len(Genre_df.Id[break_point:])):
    cur_id = Genre_df.Id[k]
    Book_Gerne, Book_Gerne_amount = Crawler(ID = cur_id)
    for i in range(4):
        if (Book_Gerne == "") or (Book_Gerne_amount == ""):
            print(f"number {k} rerun")
            Book_Gerne, Book_Gerne_amount = Crawler(ID = cur_id)
            continue
        break
    Genre_df.iloc[break_point + k,-2] = Book_Gerne
    Genre_df.iloc[break_point + k,-1] = Book_Gerne_amount
    print(f"Book number:{k} out of 141480 ({(break_point+k)/(141810-break_point)*100:.3f}%)")
# Out:
# number 0 rerun
# Book number:0 out of 141480 (0.014%)
# Book number:1 out of 141480 (0.015%)
# From cffi callback <function _verify_callback at 0x0000027670A36288>:
# Traceback (most recent call last):
#   File "C:\Users\Austin\Anaconda3\lib\site-packages\OpenSSL\SSL.py", line 306, in wrapper
#     @wraps(callback)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     497             try:
# --> 498                 cnx.do_handshake()
#     499             except OpenSSL.SSL.WantReadError:
#
# ~\Anaconda3\lib\site-packages\OpenSSL\SSL.py in do_handshake(self)
#    1914         result = _lib.SSL_do_handshake(self._ssl)
# -> 1915         self._raise_ssl_error(self._ssl, result)
#    1916
#
# ~\Anaconda3\lib\site-packages\OpenSSL\SSL.py in _raise_ssl_error(self, ssl, result)
#    1646         else:
# -> 1647             _raise_current_error()
#    1648
#
# ~\Anaconda3\lib\site-packages\OpenSSL\_util.py in exception_from_error_queue(exception_type)
#      53
# ---> 54     raise exception_type(errors)
#      55
#
# Error: [('SSL routines', 'tls_process_server_certificate', 'certificate verify failed')]
#
# During handling of the above exception, another exception occurred:
#
# SSLError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     705                 headers=headers,
# --> 706                 chunked=chunked,
#     707             )
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381         try:
# --> 382             self._validate_conn(conn)
#     383         except (SocketTimeout, BaseSSLError) as e:
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#    1009         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1010             conn.connect()
#    1011
#
# ~\Anaconda3\lib\site-packages\urllib3\connection.py in connect(self)
#     425             ssl_context=context,
# --> 426             tls_in_tls=tls_in_tls,
#     427         )
#
# ~\Anaconda3\lib\site-packages\urllib3\util\ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     449         ssl_sock = _ssl_wrap_socket_impl(
# --> 450             sock, context, tls_in_tls, server_hostname=server_hostname
#     451         )
#
# ~\Anaconda3\lib\site-packages\urllib3\util\ssl_.py in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     492     if server_hostname:
# --> 493         return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#     494     else:
#
# ~\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     503             except OpenSSL.SSL.Error as e:
# --> 504                 raise ssl.SSLError("bad handshake: %r" % e)
#     505             break
#
# SSLError: ("bad handshake: Error([('SSL routines', 'tls_process_server_certificate', 'certificate verify failed')])",)
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     755             retries = retries.increment(
# --> 756                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     757             )
#
# ~\Anaconda3\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     573         if new_retry.is_exhausted():
# --> 574             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     575
#
# MaxRetryError: HTTPSConnectionPool(host='www.goodreads.com', port=443): Max retries exceeded with url: /book/show/5 (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'tls_process_server_certificate', 'certificate verify failed')])")))
#
# During handling of the above exception, another exception occurred:
#
# SSLError                                  Traceback (most recent call last)
# <ipython-input-201-cf8033f4dbaf> in <module>
#       2 for k in range(len(Genre_df.Id[break_point:])):
#       3     cur_id = Genre_df.Id[k]
# ----> 4     Book_Gerne, Book_Gerne_amount = Crawler(ID = cur_id)
#       5     for i in range(4):
#       6         if (Book_Gerne == "") or (Book_Gerne_amount == ""):
#
# <ipython-input-199-f191fb1885f6> in Crawler(ID)
#       3     genre_string = ""
#       4     genre_users_string = ""
# ----> 5     response  = requests.get(f"https://www.goodreads.com/book/show/{ID}")
#       6     soup = bs4.BeautifulSoup(response.text, "html.parser")
#       7     genre_list = soup.find_all("a", {"class": "bookPageGenreLink"})
#
# ~\Anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~\Anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     512             if isinstance(e.reason, _SSLError):
#     513                 # This branch is for urllib3 v1.22 and later.
# --> 514                 raise SSLError(e, request=request)
#     515
#     516             raise ConnectionError(e, request=request)
#
# SSLError: HTTPSConnectionPool(host='www.goodreads.com', port=443): Max retries exceeded with url: /book/show/5 (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'tls_process_server_certificate', 'certificate verify failed')])")))

# %%
sample_df = Genre_df[Genre_df.Genre!=""]

# %%
Genre_df.head(20)
# Out:
#     Id                                               Name RatingDist1  \
# 0    2  Harry Potter and the Order of the Phoenix (Har...     1:12455
# 1    4  Harry Potter and the Chamber of Secrets (Harry...     1:11896
# 2    5  Harry Potter and the Prisoner of Azkaban (Harr...     1:10128
# 3   13  The Ultimate Hitchhiker's Guide to the Galaxy ...      1:3443
# 4   18  The Ultimate Hitchhiker's Guide (Hitchhiker's ...      1:3443
# 5   21               A Short History of Nearly Everything      1:5140
# 6   22                        Bill Bryson's African Diary       1:249
# 7   24                             In a Sunburned Country       1:987
# 8   25  I'm a Stranger Here Myself: Notes on Returning...       1:741
# 9   26  The Lost Continent: Travels in Small Town America      1:1373
# 10  27          Neither Here nor There: Travels in Europe      1:1172
# 11  28                          Notes from a Small Island      1:1487
# 12  29  The Mother Tongue: English and How It Got That...       1:490
# 13  34  The Fellowship of the Ring (The Lord of the Ri...     1:45879
# 14  38                      The Lord of the Rings Box Set      1:5774
# 15  53  Guts: The True Stories behind Hatchet and the ...        1:54
# 16  66         The Changeling (Daughters of England, #15)         1:2
# 17  74    The John McPhee Reader (John McPhee Reader, #1)         1:2
# 18  77                              The Control of Nature        1:25
# 19  78                         Annals of the Former World        1:56
#
#    pagesNumber RatingDist4 RatingDistTotal PublishMonth PublishDay  \
# 0          870    4:604283   total:2358637            1          9
# 1          352    4:706082   total:2560657            1         11
# 2          435    4:630534   total:2610317            1          5
# 3          815     4:75683    total:274268           30          4
# 4          815     4:75683    total:274268           17          1
# 5          544     4:94040    total:276166           14          9
# 6           55      4:2409      total:8393            3         12
# 7          335     4:34941     total:85287           15          5
# 8          304     4:22652     total:56082           28          6
# 9          299     4:18427     total:49012           28          8
# 10         254     4:20655     total:54388           28          3
# 11         324     4:35153     total:89491           28          5
# 12         270     4:13483     total:33416           28          9
# 13         398    4:593379   total:2255826            5          9
# 14        1223    4:126639    total:539513           19          9
# 15         144       4:830      total:2400           23          1
# 16         369       4:151       total:439           28          8
# 17         416       4:224       total:624            1          6
# 18         288      4:1458      total:3747            1          9
# 19         720      4:1003      total:3472            6          1
#
#                   Publisher_x CountsOfReview  ... PagesNumber  \
# 0             Scholastic Inc.          29770  ...         NaN
# 1                  Scholastic            244  ...         NaN
# 2             Scholastic Inc.          37093  ...         NaN
# 3               Del Rey Books           4119  ...         NaN
# 4                 Wings Books            194  ...         NaN
# 5              Broadway Books           9545  ...         NaN
# 6              Broadway Books            503  ...         NaN
# 7              Broadway Books           4298  ...         NaN
# 8              Broadway Books           2224  ...         NaN
# 9   William Morrow Paperbacks           2276  ...         NaN
# 10  William Morrow Paperbacks           2264  ...         NaN
# 11  William Morrow Paperbacks           3335  ...         NaN
# 12  William Morrow Paperbacks           2123  ...         NaN
# 13  Houghton Mifflin Harcourt          13935  ...         NaN
# 14                        NaN             19  ...         NaN
# 15            Delacorte Press            336  ...         NaN
# 16                  Ivy Books             13  ...         NaN
# 17  Farrar, Straus and Giroux             37  ...         NaN
# 18  Farrar, Straus and Giroux            305  ...         NaN
# 19  Farrar, Straus and Giroux            227  ...         NaN
#
#                                            Book-Title       Book-Author  \
# 0   Harry Potter and the Order of the Phoenix (Boo...     J. K. Rowling
# 1   Harry Potter and the Chamber of Secrets (Harry...     J. K. Rowling
# 2   Harry Potter and the Prisoner of Azkaban (Harr...      J.K. Rowling
# 3       The Ultimate Hitchhiker's Guide to the Galaxy     DOUGLAS ADAMS
# 4                     The Ultimate Hitchhiker's Guide     Douglas Adams
# 5                A Short History of Nearly Everything       BILL BRYSON
# 6                         Bill Bryson's African Diary       BILL BRYSON
# 7                              In a Sunburned Country       Bill Bryson
# 8   I'm a Stranger Here Myself: Notes on Returning...       Bill Bryson
# 9   The Lost Continent: Travels in Small-Town America       Bill Bryson
# 10          Neither Here nor There: Travels in Europe       Bill Bryson
# 11                          Notes from a Small Island       Bill Bryson
# 12                                  The Mother Tongue       Bill Bryson
# 13  The Fellowship of the Ring (The Lord of the Ri...  J. R. R. Tolkien
# 14                              The Lord of the Rings  J. R. R. Tolkien
# 15  Guts : The True Stories Behind Hatchet and the...      Gary Paulsen
# 16                                     The Changeling     Philippa Carr
# 17                             The John McPhee Reader       John McPhee
# 18                              The Control of Nature       John McPhee
# 19                         Annals of the Former World       John McPhee
#
#     Year-Of-Publication                    Publisher_y  \
# 0                  2004          Scholastic Paperbacks
# 1                  2003         Arthur A. Levine Books
# 2                  2004          Scholastic Paperbacks
# 3                  2002                        Del Rey
# 4                  1996  Random House Value Publishing
# 5                  2004                       Broadway
# 6                  2002                       Broadway
# 7                  2001                 Broadway Books
# 8                  2000                 Broadway Books
# 9                  1990                      Perennial
# 10                 1999                      Perennial
# 11                 1997                      Perennial
# 12                 1991                      Perennial
# 13                 2003       Houghton Mifflin Company
# 14                 2001       Houghton Mifflin Company
# 15                 2001                Delacorte Press
# 16                 1990                      Ivy Books
# 17                 1982      Farrar, Straus and Giroux
# 18                 1990                  Noonday Press
# 19                 2000      Farrar, Straus and Giroux
#
#                                           Image-URL-S  \
# 0   http://images.amazon.com/images/P/0439358078.0...
# 1   http://images.amazon.com/images/P/0439554896.0...
# 2   http://images.amazon.com/images/P/043965548X.0...
# 3   http://images.amazon.com/images/P/0345453743.0...
# 4   http://images.amazon.com/images/P/0517149257.0...
# 5   http://images.amazon.com/images/P/076790818X.0...
# 6   http://images.amazon.com/images/P/0767915062.0...
# 7   http://images.amazon.com/images/P/0767903862.0...
# 8   http://images.amazon.com/images/P/076790382X.0...
# 9   http://images.amazon.com/images/P/0060920084.0...
# 10  http://images.amazon.com/images/P/0380713802.0...
# 11  http://images.amazon.com/images/P/0380727501.0...
# 12  http://images.amazon.com/images/P/0380715430.0...
# 13  http://images.amazon.com/images/P/0618346252.0...
# 14  http://images.amazon.com/images/P/0618153977.0...
# 15  http://images.amazon.com/images/P/0385326505.0...
# 16  http://images.amazon.com/images/P/0449146979.0...
# 17  http://images.amazon.com/images/P/0374517193.0...
# 18  http://images.amazon.com/images/P/0374522596.0...
# 19  http://images.amazon.com/images/P/0374518734.0...
#
#                                           Image-URL-M  \
# 0   http://images.amazon.com/images/P/0439358078.0...
# 1   http://images.amazon.com/images/P/0439554896.0...
# 2   http://images.amazon.com/images/P/043965548X.0...
# 3   http://images.amazon.com/images/P/0345453743.0...
# 4   http://images.amazon.com/images/P/0517149257.0...
# 5   http://images.amazon.com/images/P/076790818X.0...
# 6   http://images.amazon.com/images/P/0767915062.0...
# 7   http://images.amazon.com/images/P/0767903862.0...
# 8   http://images.amazon.com/images/P/076790382X.0...
# 9   http://images.amazon.com/images/P/0060920084.0...
# 10  http://images.amazon.com/images/P/0380713802.0...
# 11  http://images.amazon.com/images/P/0380727501.0...
# 12  http://images.amazon.com/images/P/0380715430.0...
# 13  http://images.amazon.com/images/P/0618346252.0...
# 14  http://images.amazon.com/images/P/0618153977.0...
# 15  http://images.amazon.com/images/P/0385326505.0...
# 16  http://images.amazon.com/images/P/0449146979.0...
# 17  http://images.amazon.com/images/P/0374517193.0...
# 18  http://images.amazon.com/images/P/0374522596.0...
# 19  http://images.amazon.com/images/P/0374518734.0...
#
#                                           Image-URL-L  \
# 0   http://images.amazon.com/images/P/0439358078.0...
# 1   http://images.amazon.com/images/P/0439554896.0...
# 2   http://images.amazon.com/images/P/043965548X.0...
# 3   http://images.amazon.com/images/P/0345453743.0...
# 4   http://images.amazon.com/images/P/0517149257.0...
# 5   http://images.amazon.com/images/P/076790818X.0...
# 6   http://images.amazon.com/images/P/0767915062.0...
# 7   http://images.amazon.com/images/P/0767903862.0...
# 8   http://images.amazon.com/images/P/076790382X.0...
# 9   http://images.amazon.com/images/P/0060920084.0...
# 10  http://images.amazon.com/images/P/0380713802.0...
# 11  http://images.amazon.com/images/P/0380727501.0...
# 12  http://images.amazon.com/images/P/0380715430.0...
# 13  http://images.amazon.com/images/P/0618346252.0...
# 14  http://images.amazon.com/images/P/0618153977.0...
# 15  http://images.amazon.com/images/P/0385326505.0...
# 16  http://images.amazon.com/images/P/0449146979.0...
# 17  http://images.amazon.com/images/P/0374517193.0...
# 18  http://images.amazon.com/images/P/0374522596.0...
# 19  http://images.amazon.com/images/P/0374518734.0...
#
#                                                 Genre  \
# 0   Fantasy|Young Adult|Fiction|Fantasy|Magic|Chil...
# 1   Fantasy|Fiction|Young Adult|Fantasy|Magic|Chil...
# 2   Fantasy|Young Adult|Fiction|Fantasy|Magic|Chil...
# 3   Science Fiction|Fiction|Humor|Fantasy|Classics...
# 4   Science Fiction|Fiction|Humor|Fantasy|Classics...
# 5   Nonfiction|Science|History|Audiobook|Humor|Sci...
# 6   Travel|Nonfiction|Cultural|Africa|Autobiograph...
# 7   Travel|Nonfiction|Humor|Cultural|Australia|Aut...
# 8   Nonfiction|Travel|Humor|Autobiography|Memoir|W...
# 9   Travel|Nonfiction|Humor|Autobiography|Memoir|A...
# 10  Travel|Nonfiction|Humor|Autobiography|Memoir|B...
# 11  Travel|Nonfiction|Humor|Autobiography|Memoir|E...
# 12  Nonfiction|History|Humanities|Language|Humanit...
# 13  Fantasy|Classics|Fiction|Adventure|Science Fic...
# 14  Classics|Fiction|Adventure|Science Fiction Fan...
# 15  Nonfiction|Biography|Adventure|Adventure|Survi...
# 16  Historical|Historical Fiction|Romance|Fiction|...
# 17  Nonfiction|Writing|Essays|Writing|Journalism|H...
# 18  Nonfiction|Science|Environment|Nature|History|...
# 19  Science|Nonfiction|Science|Geology|History|Env...
#
#                                     Genre_user_amount
# 0   53,448|16,458|15,012|4,161|3,034|2,212|2,068|2...
# 1   57,961|16,754|16,407|4,584|3,892|3,094|2,521|2...
# 2   57,548|16,609|16,475|4,543|3,786|2,887|2,512|2...
# 3    3,415|2,789|1,477|1,157|817|474|416|181|179|106|
# 4    3,415|2,789|1,477|1,157|817|474|416|181|179|106|
# 5      9,425|7,054|5,663|655|407|274|270|251|211|189|
# 6                   491|341|164|50|47|21|20|17|15|14|
# 7          3,121|2,660|722|591|362|216|183|129|99|82|
# 8           1,718|1,381|696|394|204|151|107|80|69|64|
# 9              1,884|1,429|445|238|79|77|72|57|48|45|
# 10             2,375|1,484|429|258|80|68|55|48|46|43|
# 11          2,881|2,723|642|410|228|156|128|97|91|84|
# 12              2,294|799|728|285|210|82|75|68|64|56|
# 13  44,465|11,955|11,035|2,131|1,511|1,489|1,327|9...
# 14       5,518|5,409|771|663|483|468|453|426|404|275|
# 15                         77|45|33|31|29|10|8|8|7|6|
# 16                           25|17|11|10|7|4|3|3|3|2|
# 17                             44|24|9|9|6|6|5|5|5|4|
# 18                   192|128|87|49|47|40|35|16|12|11|
# 19                 303|239|117|111|66|41|38|22|13|11|
#
# [20 rows x 30 columns]

# %%
Crawler(ID=21)
# Out:
# ('Nonfiction|Science|History|Audiobook|Humor|Science|Physics|Science|Popular Science|Historical|',
#  '9,425|7,054|5,663|655|407|274|270|251|211|189|')

# %%
sum(Genre_df.Genre!="")
# Out:
# 740

# %%
sample_df.sort_values(by = "Id")
# Out:
#             Id                                               Name RatingDist1  \
# 6           22                        Bill Bryson's African Diary       1:249
# 14          38                      The Lord of the Rings Box Set      1:5774
# 38         163                                    The Untouchable        1:50
# 42         245                            Henry Miller on Writing         1:8
# 44         247                               Quiet Days in Clichy       1:110
# ...        ...                                                ...         ...
# 15802  1095098                     Complete Book of Tarot Spreads         1:4
# 15817  1095420  The Cat Whisperer: The Secret of How to Talk t...         1:9
# 15897  1097415                                          Der Fürst      1:5709
# 15992  1099466    The Worst Witch Strikes Again (Worst Witch, #2)        1:31
# 16012  1099853  The Monk in the Garden : The Lost and Found Ge...         1:4
#
#       pagesNumber RatingDist4 RatingDistTotal PublishMonth PublishDay  \
# 6              55      4:2409      total:8393            3         12
# 14           1223    4:126639    total:539513           19          9
# 38            368      4:1104      total:2686           30          6
# 42            217       4:348      total:1019            1          2
# 44            154      4:1507      total:4228           13          1
# ...           ...         ...             ...          ...        ...
# 15802         192        4:67       total:168            1          6
# 15817         184        4:73       total:239            1          5
# 15897         166     4:86970    total:249095            1          1
# 15992          92      4:1293      total:3649            1         10
# 16012         304       4:115       total:283           25          5
#
#                      Publisher_x CountsOfReview  ... PagesNumber  \
# 6                 Broadway Books            503  ...         NaN
# 14                           NaN             19  ...         NaN
# 38                 Vintage Books            218  ...         NaN
# 42     New Directions Publishing             52  ...         NaN
# 44                   Grove Press            143  ...         NaN
# ...                          ...            ...  ...         ...
# 15802                   Sterling             12  ...         NaN
# 15817          B.E.S. Publishing             19  ...         NaN
# 15897           Insel, Frankfurt              0  ...         NaN
# 15992                     Puffin             91  ...         NaN
# 16012  Houghton Mifflin Harcourt              3  ...         NaN
#
#                                               Book-Title          Book-Author  \
# 6                            Bill Bryson's African Diary          BILL BRYSON
# 14                                 The Lord of the Rings     J. R. R. Tolkien
# 38                                       The Untouchable        John Banville
# 42     Henry Miller on Writing (New Directions Paperb...         Henry Miller
# 44                                  Quiet Days in Clichy         Henry Miller
# ...                                                  ...                  ...
# 15802                     Complete Book of Tarot Spreads        Evelin Burger
# 15817  The Cat Whisperer: The Secret of How to Talk t...       Claire Bessant
# 15897                                      Der FÃ?Â¼rst.  Niccolo Machiavelli
# 15992  The Worst Witch Strikes Again (Young Puffin Bo...          Jill Murphy
# 16012  The Monk in the Garden : The Lost and Found Ge...  Robin Marantz Henig
#
#        Year-Of-Publication                            Publisher_y  \
# 6                     2002                               Broadway
# 14                    2001               Houghton Mifflin Company
# 38                    1998                      Vintage Books USA
# 42                    1964  New Directions Publishing Corporation
# 44                    1987                            Grove Press
# ...                    ...                                    ...
# 15802                 1997                    Sterling Publishing
# 15817                 2002            Barron's Educational Series
# 15897                 1990                       Insel, Frankfurt
# 15992                 1991                            Penguin USA
# 16012                 2000               Houghton Mifflin Company
#
#                                              Image-URL-S  \
# 6      http://images.amazon.com/images/P/0767915062.0...
# 14     http://images.amazon.com/images/P/0618153977.0...
# 38     http://images.amazon.com/images/P/0679767479.0...
# 42     http://images.amazon.com/images/P/0811201120.0...
# 44     http://images.amazon.com/images/P/080213016X.0...
# ...                                                  ...
# 15802  http://images.amazon.com/images/P/080699505X.0...
# 15817  http://images.amazon.com/images/P/0764121650.0...
# 15897  http://images.amazon.com/images/P/3458329072.0...
# 15992  http://images.amazon.com/images/P/0140313486.0...
# 16012  http://images.amazon.com/images/P/0395977657.0...
#
#                                              Image-URL-M  \
# 6      http://images.amazon.com/images/P/0767915062.0...
# 14     http://images.amazon.com/images/P/0618153977.0...
# 38     http://images.amazon.com/images/P/0679767479.0...
# 42     http://images.amazon.com/images/P/0811201120.0...
# 44     http://images.amazon.com/images/P/080213016X.0...
# ...                                                  ...
# 15802  http://images.amazon.com/images/P/080699505X.0...
# 15817  http://images.amazon.com/images/P/0764121650.0...
# 15897  http://images.amazon.com/images/P/3458329072.0...
# 15992  http://images.amazon.com/images/P/0140313486.0...
# 16012  http://images.amazon.com/images/P/0395977657.0...
#
#                                              Image-URL-L  \
# 6      http://images.amazon.com/images/P/0767915062.0...
# 14     http://images.amazon.com/images/P/0618153977.0...
# 38     http://images.amazon.com/images/P/0679767479.0...
# 42     http://images.amazon.com/images/P/0811201120.0...
# 44     http://images.amazon.com/images/P/080213016X.0...
# ...                                                  ...
# 15802  http://images.amazon.com/images/P/080699505X.0...
# 15817  http://images.amazon.com/images/P/0764121650.0...
# 15897  http://images.amazon.com/images/P/3458329072.0...
# 15992  http://images.amazon.com/images/P/0140313486.0...
# 16012  http://images.amazon.com/images/P/0395977657.0...
#
#                                                    Genre  \
# 6      Travel|Nonfiction|Cultural|Africa|Autobiograph...
# 14     Classics|Fiction|Adventure|Science Fiction Fan...
# 38     Fiction|Historical|Historical Fiction|Cultural...
# 42     Language|Writing|Nonfiction|Biography|Writing|...
# 44     Fiction|Literature|Classics|Novels|Adult Ficti...
# ...                                                  ...
# 15802  Occult|Tarot|Nonfiction|Reference|Occult|Divin...
# 15817                   Nonfiction|Animals|Cats|Animals|
# 15897  Classics|Philosophy|Nonfiction|Politics|Histor...
# 15992  Fantasy|Childrens|Fiction|Fantasy|Magic|Parano...
# 16012  Science|Biography|Nonfiction|History|Science|B...
#
#                                        Genre_user_amount
# 6                      491|341|164|50|47|21|20|17|15|14|
# 14          5,518|5,409|771|663|483|468|453|426|404|275|
# 38                       196|79|38|32|28|26|20|17|17|16|
# 42                               109|45|9|8|7|5|4|3|2|2|
# 44                            80|24|18|17|16|11|9|8|8|4|
# ...                                                  ...
# 15802                                 16|12|9|8|6|5|4|2|
# 15817                                         24|11|8|2|
# 15897  6,057|5,780|3,889|3,260|1,933|362|355|354|343|...
# 15992                     154|101|60|35|33|29|12|11|8|7|
# 16012                          57|29|21|18|14|5|4|3|3|2|
#
# [736 rows x 30 columns]

# %%
# sample_df.to_csv("Books_sample.csv")

# %%
# sample_df.tail(5)
# Out:
#          Id                                       Name RatingDist1  \
# 1319  10217                           Death in Kashmir        1:19
# 1374  10656             Next: The Future Just Happened        1:18
# 1394  10801                The Big Rock Candy Mountain        1:69
# 1411  10890  Traveling Mercies: Some Thoughts on Faith       1:521
# 1420  10972                Omega Path (Outlanders, #4)         1:1
#
#      pagesNumber RatingDist4 RatingDistTotal PublishMonth PublishDay  \
# 1319         256       4:702      total:1717            1         12
# 1374         240       4:628      total:1581           17          5
# 1394         563      4:2660      total:6753            1          3
# 1411         275     4:15301     total:41458           15          2
# 1420         352        4:27        total:89           23          1
#
#                 Publisher_x CountsOfReview  ... PagesNumber  \
# 1319  St. Martins Press-3PL            106  ...         NaN
# 1374  W. W. Norton  Company            106  ...         NaN
# 1394                Penguin            672  ...         NaN
# 1411                 Anchor           2309  ...         NaN
# 1420             Gold Eagle              2  ...         NaN
#
#                                              Book-Title      Book-Author  \
# 1319                        Death in Kashmir: A Mystery       M. M. Kaye
# 1374                     Next: The Future Just Happened    Michael Lewis
# 1394  The Big Rock Candy Mountain (Contemporary Amer...  Wallace Stegner
# 1411          Traveling Mercies: Some Thoughts on Faith      Anne Lamott
# 1420   Omega Path (Outlanders #4) (Outlanders , No 360)      James Axler
#
#       Year-Of-Publication                 Publisher_y  \
# 1319                 2000       St. Martin's Minotaur
# 1374                 2002  W. W. Norton &amp; Company
# 1394                 1995               Penguin Books
# 1411                 2000      Anchor Books/Doubleday
# 1420                 1998                  Gold Eagle
#
#                                             Image-URL-S  \
# 1319  http://images.amazon.com/images/P/0312263104.0...
# 1374  http://images.amazon.com/images/P/0393323528.0...
# 1394  http://images.amazon.com/images/P/0140139397.0...
# 1411  http://images.amazon.com/images/P/0385496095.0...
# 1420  http://images.amazon.com/images/P/0373638175.0...
#
#                                             Image-URL-M  \
# 1319  http://images.amazon.com/images/P/0312263104.0...
# 1374  http://images.amazon.com/images/P/0393323528.0...
# 1394  http://images.amazon.com/images/P/0140139397.0...
# 1411  http://images.amazon.com/images/P/0385496095.0...
# 1420  http://images.amazon.com/images/P/0373638175.0...
#
#                                             Image-URL-L  \
# 1319  http://images.amazon.com/images/P/0312263104.0...
# 1374  http://images.amazon.com/images/P/0393323528.0...
# 1394  http://images.amazon.com/images/P/0140139397.0...
# 1411  http://images.amazon.com/images/P/0385496095.0...
# 1420  http://images.amazon.com/images/P/0373638175.0...
#
#                                                   Genre  \
# 1319  Mystery|Cultural|India|Historical|Historical F...
# 1374  Nonfiction|Business|Science|Technology|Compute...
# 1394  Fiction|Historical|Historical Fiction|Classics...
# 1411  Nonfiction|Autobiography|Memoir|Spirituality|R...
# 1420                       Science Fiction|Apocalyptic|
#
#                            Genre_user_amount
# 1319          168|33|32|25|19|14|14|12|10|9|
# 1374                 62|42|10|9|9|8|8|5|5|4|
# 1394         323|97|62|25|25|24|17|17|17|14|
# 1411  655|530|366|339|211|163|133|103|70|59|
# 1420                                    3|3|
#
# [5 rows x 30 columns]

# %%
# os.chdir("D:\user\Documents\WebMining")

# %%
Genre_df.to_csv("All_Bookdata.csv")
